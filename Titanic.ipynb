# %%
  # !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144487 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.22-0ubuntu3~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.22-0ubuntu3~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
import os
os.chdir("/content/drive/titanic")
# !pwd
# Out:
# /content/drive/titanic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import re

from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.callbacks import ModelCheckpoint 
from keras.optimizers import Adam

# %%
# ÖN İŞLEMLER

def preprocess(data):
    
    #Kabin
    data.Cabin.fillna('0', inplace=True)
    data.loc[data.Cabin.str[0] == 'A', 'Cabin'] = 1
    data.loc[data.Cabin.str[0] == 'B', 'Cabin'] = 2
    data.loc[data.Cabin.str[0] == 'C', 'Cabin'] = 3
    data.loc[data.Cabin.str[0] == 'D', 'Cabin'] = 4
    data.loc[data.Cabin.str[0] == 'E', 'Cabin'] = 5
    data.loc[data.Cabin.str[0] == 'F', 'Cabin'] = 6
    data.loc[data.Cabin.str[0] == 'G', 'Cabin'] = 7
    data.loc[data.Cabin.str[0] == 'T', 'Cabin'] = 8
    
    # Cinsiyeti tam sayıya çevirelim
    data['Sex'].replace('female', 1, inplace=True)
    data['Sex'].replace('male', 2, inplace=True)
    
    # Gemiye biniş limanlarını tam sayıya çevirelim
    data['Embarked'].replace('S', 1, inplace=True) 
    data['Embarked'].replace('C', 2, inplace=True)
    data['Embarked'].replace('Q', 3, inplace=True)
    
    # Olmayan (NA) yaş değerlerini medyan ile dolduralım
      data['Age'].fillna(data['Age'].median(), inplace=True)
      data['Fare'].fillna(data['Fare'].median(), inplace=True)
      data['Embarked'].fillna(data['Embarked'].median(), inplace=True)
    
    # İstersek olmayan (NA) değerleri tamamen silebiliriz
    # data.dropna(subset=['Fare', 'Embarked'], inplace=True, how='any')
    return data

def group_titles(data):
    data['Names'] = data['Name'].map(lambda x: len(re.split(' ', x)))
    data['Title'] = data['Name'].map(lambda x: re.search(', (.+?) ', x).group(1))
    data['Title'].replace('Master.', 0, inplace=True)
    data['Title'].replace('Mr.', 1, inplace=True)
    data['Title'].replace(['Ms.','Mlle.', 'Miss.'], 2, inplace=True)
    data['Title'].replace(['Mme.', 'Mrs.'], 3, inplace=True)
    data['Title'].replace(['Dona.', 'Lady.', 'the Countess.', 'Capt.', 'Col.', 'Don.', 'Dr.', 'Major.', 'Rev.', 'Sir.', 'Jonkheer.', 'the'], 4, inplace=True)

def data_subset(data):
    features = ['Pclass', 'SibSp', 'Parch', 'Sex', 'Names', 'Title', 'Age', 'Cabin'] #, 'Fare', 'Embarked']
    lengh_features = len(features)
    subset = data[features]#.fillna(0)
    return subset, lengh_features

def create_model(train_set_size, input_length, num_epochs, batch_size):
    model = Sequential()
    model.add(Dense(7, input_dim=input_length, activation='softplus'))
    model.add(Dense(3, activation='softplus'))
    model.add(Dense(1, activation='softplus'))

    lr = .001
    adam0 = Adam(lr = lr)

    # Modeli derleyip ve daha iyi bir sonuç elde edildiğinde ağırlıkları kaydedelim
    model.compile(loss='binary_crossentropy', optimizer=adam0, metrics=['acc'])
    filepath = 'weights.best.hdf5'
    checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    history_model = model.fit(X_train[:train_set_size], Y_train[:train_set_size], callbacks=callbacks_list, epochs=num_epochs, batch_size=batch_size, verbose=0) #40, 32
    return model, history_model 

def plots(history):
    loss_history = history.history['loss']
    acc_history = history.history['acc']
    epochs = [(i + 1) for i in range(num_epochs)]

    ax = plt.subplot(211)
    ax.plot(epochs, loss_history, color='red')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('Error Rate\n')
    ax.set_title('Error Rate per Epoch\n')

    ax2 = plt.subplot(212)
    ax2.plot(epochs, acc_history, color='blue')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy\n')
    ax2.set_title('Accuracy per Epoch\n')

    plt.subplots_adjust(hspace=0.8)
    plt.savefig('Accuracy_loss.png')
    plt.close()

def test(batch_size):
    test = pd.read_csv('test.csv', header=0)
    test_ids = test['PassengerId']
    test = preprocess(test)
    group_titles(test)
    testdata, _ = data_subset(test)

    X_test = np.array(testdata).astype(float)

    output = model.predict(X_test, batch_size=batch_size, verbose=0)
    output = output.reshape((418,))

    # Sonuçları ondalık sayı yerine 0-1 olarak değiştiriliyor.
    #outputBin = np.zeros(0)
    #for element in output:
    #    if element <= .5:
    #         outputBin = np.append(outputBin, 0)
    #    else:
    #        outputBin = np.append(outputBin, 1)
    #output = np.array(outputBin).astype(int)

    column_1 = np.concatenate((['PassengerId'], test_ids ), axis=0 )
    column_2 = np.concatenate( ( ['Survived'], output ), axis=0 )

      f = open("output.csv", "w")
      writer = csv.writer(f)
      for i in range(len(column_1)):
          writer.writerow( [column_1[i]] + [column_2[i]])
      f.close()

# %%
# sonuçların yeniden üretilebilir olması için
seed = 7
np.random.seed(seed)
train = pd.read_csv('train.csv', header=0)

preprocess(train)
group_titles(train)


num_epochs = 100
batch_size = 32



traindata, lengh_features = data_subset(train)

Y_train = np.array(train['Survived']).astype(int)
X_train = np.array(traindata).astype(float)


train_set_size = int(.67 * len(X_train))


model, history_model = create_model(train_set_size, lengh_features, num_epochs, batch_size)

plots(history_model)


X_validation = X_train[train_set_size:]
Y_validation = Y_train[train_set_size:]


loss_and_metrics = model.evaluate(X_validation, Y_validation, batch_size=batch_size)
print ("loss_and_metrics")

test(batch_size)
# Out:
# Epoch 00001: acc improved from -inf to 0.39262, saving model to weights.best.hdf5
#
# Epoch 00002: acc did not improve from 0.39262
#
# Epoch 00003: acc did not improve from 0.39262
#
# Epoch 00004: acc improved from 0.39262 to 0.42114, saving model to weights.best.hdf5
#
# Epoch 00005: acc improved from 0.42114 to 0.60403, saving model to weights.best.hdf5
#
# Epoch 00006: acc did not improve from 0.60403
#
# Epoch 00007: acc did not improve from 0.60403
#
# Epoch 00008: acc improved from 0.60403 to 0.61577, saving model to weights.best.hdf5
#
# Epoch 00009: acc improved from 0.61577 to 0.61913, saving model to weights.best.hdf5
#
# Epoch 00010: acc did not improve from 0.61913
#
# Epoch 00011: acc improved from 0.61913 to 0.62584, saving model to weights.best.hdf5
#
# Epoch 00012: acc did not improve from 0.62584
#
# Epoch 00013: acc did not improve from 0.62584
#
# Epoch 00014: acc improved from 0.62584 to 0.63255, saving model to weights.best.hdf5
#
# Epoch 00015: acc did not improve from 0.63255
#
# Epoch 00016: acc improved from 0.63255 to 0.65268, saving model to weights.best.hdf5
#
# Epoch 00017: acc improved from 0.65268 to 0.66611, saving model to weights.best.hdf5
#
# Epoch 00018: acc improved from 0.66611 to 0.68624, saving model to weights.best.hdf5
#
# Epoch 00019: acc improved from 0.68624 to 0.69463, saving model to weights.best.hdf5
#
# Epoch 00020: acc improved from 0.69463 to 0.70638, saving model to weights.best.hdf5
#
# Epoch 00021: acc improved from 0.70638 to 0.72483, saving model to weights.best.hdf5
#
# Epoch 00022: acc improved from 0.72483 to 0.73154, saving model to weights.best.hdf5
#
# Epoch 00023: acc improved from 0.73154 to 0.73322, saving model to weights.best.hdf5
#
# Epoch 00024: acc improved from 0.73322 to 0.74832, saving model to weights.best.hdf5
#
# Epoch 00025: acc improved from 0.74832 to 0.75671, saving model to weights.best.hdf5
#
# Epoch 00026: acc improved from 0.75671 to 0.77517, saving model to weights.best.hdf5
#
# Epoch 00027: acc did not improve from 0.77517
#
# Epoch 00028: acc did not improve from 0.77517
#
# Epoch 00029: acc improved from 0.77517 to 0.77852, saving model to weights.best.hdf5
#
# Epoch 00030: acc did not improve from 0.77852
#
# Epoch 00031: acc improved from 0.77852 to 0.78020, saving model to weights.best.hdf5
#
# Epoch 00032: acc did not improve from 0.78020
#
# Epoch 00033: acc did not improve from 0.78020
#
# Epoch 00034: acc did not improve from 0.78020
#
# Epoch 00035: acc improved from 0.78020 to 0.79866, saving model to weights.best.hdf5
#
# Epoch 00036: acc did not improve from 0.79866
#
# Epoch 00037: acc did not improve from 0.79866
#
# Epoch 00038: acc did not improve from 0.79866
#
# Epoch 00039: acc did not improve from 0.79866
#
# Epoch 00040: acc did not improve from 0.79866
#
# Epoch 00041: acc did not improve from 0.79866
#
# Epoch 00042: acc did not improve from 0.79866
#
# Epoch 00043: acc did not improve from 0.79866
#
# Epoch 00044: acc did not improve from 0.79866
#
# Epoch 00045: acc did not improve from 0.79866
#
# Epoch 00046: acc did not improve from 0.79866
#
# Epoch 00047: acc did not improve from 0.79866
#
# Epoch 00048: acc did not improve from 0.79866
#
# Epoch 00049: acc improved from 0.79866 to 0.80034, saving model to weights.best.hdf5
#
# Epoch 00050: acc did not improve from 0.80034
#
# Epoch 00051: acc did not improve from 0.80034
#
# Epoch 00052: acc did not improve from 0.80034
#
# Epoch 00053: acc did not improve from 0.80034
#
# Epoch 00054: acc did not improve from 0.80034
#
# Epoch 00055: acc did not improve from 0.80034
#
# Epoch 00056: acc did not improve from 0.80034
#
# Epoch 00057: acc did not improve from 0.80034
#
# Epoch 00058: acc improved from 0.80034 to 0.80201, saving model to weights.best.hdf5
#
# Epoch 00059: acc did not improve from 0.80201
#
# Epoch 00060: acc improved from 0.80201 to 0.80537, saving model to weights.best.hdf5
#
# Epoch 00061: acc did not improve from 0.80537
#
# Epoch 00062: acc improved from 0.80537 to 0.80705, saving model to weights.best.hdf5
#
# Epoch 00063: acc did not improve from 0.80705
#
# Epoch 00064: acc did not improve from 0.80705
#
# Epoch 00065: acc did not improve from 0.80705
#
# Epoch 00066: acc did not improve from 0.80705
#
# Epoch 00067: acc did not improve from 0.80705
#
# Epoch 00068: acc did not improve from 0.80705
#
# Epoch 00069: acc did not improve from 0.80705
#
# Epoch 00070: acc did not improve from 0.80705
#
# Epoch 00071: acc did not improve from 0.80705
#
# Epoch 00072: acc did not improve from 0.80705
#
# Epoch 00073: acc did not improve from 0.80705
#
# Epoch 00074: acc improved from 0.80705 to 0.80872, saving model to weights.best.hdf5
#
# Epoch 00075: acc did not improve from 0.80872
#
# Epoch 00076: acc did not improve from 0.80872
#
# Epoch 00077: acc did not improve from 0.80872
#
# Epoch 00078: acc did not improve from 0.80872
#
# Epoch 00079: acc did not improve from 0.80872
#
# Epoch 00080: acc did not improve from 0.80872
#
# Epoch 00081: acc improved from 0.80872 to 0.81208, saving model to weights.best.hdf5
#
# Epoch 00082: acc did not improve from 0.81208
#
# Epoch 00083: acc did not improve from 0.81208
#
# Epoch 00084: acc did not improve from 0.81208
#
# Epoch 00085: acc did not improve from 0.81208
#
# Epoch 00086: acc did not improve from 0.81208
#
# Epoch 00087: acc did not improve from 0.81208
#
# Epoch 00088: acc did not improve from 0.81208
#
# Epoch 00089: acc did not improve from 0.81208
#
# Epoch 00090: acc did not improve from 0.81208
#
# Epoch 00091: acc did not improve from 0.81208
#
# Epoch 00092: acc did not improve from 0.81208
#
# Epoch 00093: acc did not improve from 0.81208
#
# Epoch 00094: acc did not improve from 0.81208
#
# Epoch 00095: acc did not improve from 0.81208
#
# Epoch 00096: acc improved from 0.81208 to 0.81376, saving model to weights.best.hdf5
#
# Epoch 00097: acc did not improve from 0.81376
#
# Epoch 00098: acc did not improve from 0.81376
#
# Epoch 00099: acc did not improve from 0.81376
#
# Epoch 00100: acc did not improve from 0.81376
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4757 - acc: 0.7932
# loss_and_metrics
